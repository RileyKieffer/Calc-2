# %% [markdown]
# <a href="https://colab.research.google.com/github/RileyKieffer/Calc-2/blob/main/Project_1_Riley_Kieffer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Conisder the function f(x)=1/(sqrt(ax+1))

# %% [markdown]
#   a. Graph from 0-1

# %%
from sympy import *
import math
x = symbols('x')
a = 11

# %%
y = (1/(sqrt((a*x)+1)) )
plot(y,(x,0,1))

# %% [markdown]
# b. estimate area

# %% [markdown]
# The area under the curve looks around to be around the sqrt(2)+.2

# %%
integrate(y,(x,0,1))
# Out:
# -2/11 + 4*sqrt(3)/11

# %% [markdown]
# 2. Consider functions
#   y=e^x, and y=sqrt(ax)+1

# %% [markdown]
# a. graph functions on same graph

# %%
fun1=E**x
fun2=sqrt(11*x)+1
plot(fun1,fun2,(x,0,2))

# %% [markdown]
# b. find points of intersection
# first intersection is at (0,1)

# %%
nsolve(fun1-fun2,x,1.65)
# Out:
# 1.66348094130958

# %% [markdown]
# Find Area Between Curves

# %%
integrate(fun1-fun2,(x,0,1.65))
# Out:
# 2.55697982717985 - 1.41297558365316*sqrt(11)

# %% [markdown]
# Find rotation about y axis

# %%
(2*math.pi*(integrate(fun1-fun2,(x,0,1.65))))
# Out:
# 16.065978080891 - 8.87798742661306*sqrt(11)

# %% [markdown]
# Find Integral on left hand side

# %%
left=integrate(ln(x)**11,x)
left
# Out:
# x*log(x)**11 - 11*x*log(x)**10 + 110*x*log(x)**9 - 990*x*log(x)**8 + 7920*x*log(x)**7 - 55440*x*log(x)**6 + 332640*x*log(x)**5 - 1663200*x*log(x)**4 + 6652800*x*log(x)**3 - 19958400*x*log(x)**2 + 39916800*x*log(x) - 39916800*x

# %% [markdown]
# The reduction formula is better because it makes equations smaller and easier to read and process

# %%
right=x*ln(x)*11-11*integrate(ln(x)**10,x)
right
# Out:
# -11*x*log(x)**10 + 110*x*log(x)**9 - 990*x*log(x)**8 + 7920*x*log(x)**7 - 55440*x*log(x)**6 + 332640*x*log(x)**5 - 1663200*x*log(x)**4 + 6652800*x*log(x)**3 - 19958400*x*log(x)**2 + 39916811*x*log(x) - 39916800*x
